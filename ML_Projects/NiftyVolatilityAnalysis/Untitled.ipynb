# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("NIFTY_5Y.csv")
print(df.head())
# Out:
#          Date         Close          High           Low          Open  Volume
# 0  2021-03-16  14910.450195  15051.599609  14890.650391  14996.099609     100
# 1  2021-03-17  14721.299805  14956.549805  14696.049805  14946.549805     100
# 2  2021-03-18  14557.849609  14875.200195  14478.599609  14855.500000  542200
# 3  2021-03-19  14744.000000  14788.250000  14350.099609  14471.150391  919200
# 4  2021-03-22  14736.400391  14763.900391  14597.849609  14736.299805  459000

# %%
# pct_change() --> This function calculates the percentage change
# between the current row and the previous row.
df['Daily Return'] = df['Close'].pct_change(fill_method=None)
print(df.head())
# Out:
#          Date         Close          High           Low          Open  Volume  \
# 0  2021-03-16  14910.450195  15051.599609  14890.650391  14996.099609     100
# 1  2021-03-17  14721.299805  14956.549805  14696.049805  14946.549805     100
# 2  2021-03-18  14557.849609  14875.200195  14478.599609  14855.500000  542200
# 3  2021-03-19  14744.000000  14788.250000  14350.099609  14471.150391  919200
# 4  2021-03-22  14736.400391  14763.900391  14597.849609  14736.299805  459000
#
#    Daily Return
# 0           NaN
# 1     -0.012686
# 2     -0.011103
# 3      0.012787
# 4     -0.000515

# %%
# Calculate Standard Deviation to calculate Volatility
volatility = df['Daily Return'].std()
print('Volatility ', volatility)
# Out:
# Volatility  0.008595204559857773

# %%
# Identify overall movement in a month 20 days ~ 1 month
df['Volatility'] = df['Daily Return'].rolling(window=20).std()
print('Rolling Volatility ', volatility)
# Out:
# Rolling Volatility  0.008595204559857773

# %%
# Calculate Moving Average 20 and 50
df['MA20']=df['Close'].rolling(window=20).mean()
df['MA50']=df['Close'].rolling(window=50).mean()
# print(df.tail())

# %%
# Calculate Momentum - if the value is positive then Trend is up else down
df['Momentum'] = df['Close'] - df['Close'].shift(10)
# print(df.tail())
# print(df.columns)

# %%
# Calculate RSI to identify Over bought/sold condition
delta = df['Close'].diff()
# print('delta', delta)
gain = (delta.where(delta > 0, 0)).rolling(14).mean()
loss = (-delta.where(delta < 0, 0)).rolling(14).mean()
print('gain', gain)
print('loss', loss)
rs = gain / loss
df['RSI'] = 100 - (100 / (1+rs))
print('RSI', df['RSI'])
# Out:
# gain 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#           ...
# 1231    67.389230
# 1232    60.678571
# 1233    60.678571
# 1234    52.328544
# 1235    55.767857
# Name: Close, Length: 1236, dtype: float64
# loss 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#            ...
# 1231    171.946429
# 1232    200.142857
# 1233    190.335658
# 1234    225.196429
# 1235    225.196429
# Name: Close, Length: 1236, dtype: float64
# RSI 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#           ...
# 1231    28.156786
# 1232    23.264412
# 1233    24.173359
# 1234    18.855436
# 1235    19.848735
# Name: RSI, Length: 1236, dtype: float64

# %%
df = df.dropna()

# %%
df.head()
# Out:
#           Date         Close          High           Low          Open  \
# 49  2021-05-31  15582.799805  15606.349609  15374.000000  15437.750000
# 50  2021-06-01  15574.849609  15660.750000  15528.299805  15629.650391
# 51  2021-06-02  15576.200195  15597.450195  15459.849609  15520.349609
# 52  2021-06-03  15690.349609  15705.099609  15611.000000  15655.549805
# 53  2021-06-04  15670.250000  15733.599609  15622.349609  15712.500000
#
#     Volume  Daily Return  Volatility          MA20          MA50    Momentum  \
# 49  436000      0.009533    0.008261  14983.525000  14774.716973  659.649414
# 50  409600     -0.000510    0.008276  15030.559961  14788.004961  466.750000
# 51  428600      0.000087    0.007775  15084.544971  14805.102969  546.049805
# 52  410200      0.007328    0.007745  15138.169971  14827.752969  784.299805
# 53  414200     -0.001281    0.007765  15185.442480  14846.277969  494.950195
#
#           RSI
# 49  70.349202
# 50  74.298645
# 51  82.895812
# 52  85.340824
# 53  80.940956
