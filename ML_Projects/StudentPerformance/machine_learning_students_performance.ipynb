# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error

# %%
df=pd.read_csv('StudentsPerformance.csv')
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
# df['total_score']=df['math score']+df['reading score']+df['writing score']
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [1000 rows x 8 columns]

# %%
# df.drop(['math score', 'reading score','writing score'], axis=1, inplace=True)

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [1000 rows x 8 columns]

# %%
df['gender']=df['gender'].map({'female':0,'male':1})

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0         0        group B           bachelor's degree      standard
# 1         0        group C                some college      standard
# 2         0        group B             master's degree      standard
# 3         1        group A          associate's degree  free/reduced
# 4         1        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995       0        group E             master's degree      standard
# 996       1        group C                 high school  free/reduced
# 997       0        group C                 high school  free/reduced
# 998       0        group D                some college      standard
# 999       0        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [1000 rows x 8 columns]

# %%
df['race/ethnicity'].value_counts()
# Out:
# race/ethnicity
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: count, dtype: int64

# %%
df['parental level of education'].value_counts()
edu_order = {
    "some high school" : 1,
    "high school" : 2,
    "some college" : 3,
    "associate's degree" : 4,
    "bachelor's degree" : 5,
    "master's degree" : 6
}
df['parental level of education'] = df['parental level of education'].map(edu_order)

# %%
df['lunch'].value_counts()
# Out:
# lunch
# standard        645
# free/reduced    355
# Name: count, dtype: int64

# %%
df['test preparation course'].value_counts()
# Out:
# test preparation course
# none         642
# completed    358
# Name: count, dtype: int64

# %%
df['lunch']=df['lunch'].map({'free/reduced':0,'standard':1})

# %%
df['test preparation course']=df['test preparation course'].map({'none':0,'completed':1})

# %%
df_race=pd.get_dummies(df['race/ethnicity'], drop_first=True)
df_race
# Out:
#      group B  group C  group D  group E
# 0       True    False    False    False
# 1      False     True    False    False
# 2       True    False    False    False
# 3      False    False    False    False
# 4      False     True    False    False
# ..       ...      ...      ...      ...
# 995    False    False    False     True
# 996    False     True    False    False
# 997    False     True    False    False
# 998    False    False     True    False
# 999    False    False     True    False
#
# [1000 rows x 4 columns]

# %%
df=pd.concat([df, df_race], axis=1)
df.drop(['race/ethnicity'], axis=1, inplace=True)

# %%
df
# Out:
#      gender  parental level of education  lunch  test preparation course  \
# 0         0                            5      1                        0
# 1         0                            3      1                        1
# 2         0                            6      1                        0
# 3         1                            4      0                        0
# 4         1                            3      1                        0
# ..      ...                          ...    ...                      ...
# 995       0                            6      1                        1
# 996       1                            2      0                        0
# 997       0                            2      0                        1
# 998       0                            3      1                        1
# 999       0                            3      0                        0
#
#      math score  reading score  writing score  group B  group C  group D  \
# 0            72             72             74     True    False    False
# 1            69             90             88    False     True    False
# 2            90             95             93     True    False    False
# 3            47             57             44    False    False    False
# 4            76             78             75    False     True    False
# ..          ...            ...            ...      ...      ...      ...
# 995          88             99             95    False    False    False
# 996          62             55             55    False     True    False
# 997          59             71             65    False     True    False
# 998          68             78             77    False    False     True
# 999          77             86             86    False    False     True
#
#      group E
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# ..       ...
# 995     True
# 996    False
# 997    False
# 998    False
# 999    False
#
# [1000 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   int64
#  1   parental level of education  1000 non-null   int64
#  2   lunch                        1000 non-null   int64
#  3   test preparation course      1000 non-null   int64
#  4   math score                   1000 non-null   int64
#  5   reading score                1000 non-null   int64
#  6   writing score                1000 non-null   int64
#  7   group B                      1000 non-null   bool
#  8   group C                      1000 non-null   bool
#  9   group D                      1000 non-null   bool
#  10  group E                      1000 non-null   bool
# dtypes: bool(4), int64(7)
# memory usage: 58.7 KB

# %%
df
# Out:
#      gender  parental level of education  lunch  test preparation course  \
# 0         0                            5      1                        0
# 1         0                            3      1                        1
# 2         0                            6      1                        0
# 3         1                            4      0                        0
# 4         1                            3      1                        0
# ..      ...                          ...    ...                      ...
# 995       0                            6      1                        1
# 996       1                            2      0                        0
# 997       0                            2      0                        1
# 998       0                            3      1                        1
# 999       0                            3      0                        0
#
#      math score  reading score  writing score  group B  group C  group D  \
# 0            72             72             74     True    False    False
# 1            69             90             88    False     True    False
# 2            90             95             93     True    False    False
# 3            47             57             44    False    False    False
# 4            76             78             75    False     True    False
# ..          ...            ...            ...      ...      ...      ...
# 995          88             99             95    False    False    False
# 996          62             55             55    False     True    False
# 997          59             71             65    False     True    False
# 998          68             78             77    False    False     True
# 999          77             86             86    False    False     True
#
#      group E
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# ..       ...
# 995     True
# 996    False
# 997    False
# 998    False
# 999    False
#
# [1000 rows x 11 columns]

# %%
# X = df[['gender', 'test preparation course', 'lunch', 'group B',	'group C',	'group D',	'group E','parental level of education']]
X = df.drop('math score', axis=1)
y = df['math score']
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   int64
#  1   parental level of education  1000 non-null   int64
#  2   lunch                        1000 non-null   int64
#  3   test preparation course      1000 non-null   int64
#  4   math score                   1000 non-null   int64
#  5   reading score                1000 non-null   int64
#  6   writing score                1000 non-null   int64
#  7   group B                      1000 non-null   bool
#  8   group C                      1000 non-null   bool
#  9   group D                      1000 non-null   bool
#  10  group E                      1000 non-null   bool
# dtypes: bool(4), int64(7)
# memory usage: 58.7 KB

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train_scaled = sc.fit_transform(X_train)
X_test_scaled = sc.transform(X_test)

# %%
model = LinearRegression()
model.fit(X_train_scaled, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test_scaled)

# %%
r2 = r2_score(y_test, y_pred)
print(r2)
# Out:
# 0.8627684036655168
